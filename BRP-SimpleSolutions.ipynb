# %%
import os
os.getcwd()
os.chdir('/content/drive/MyDrive/BRP')

# %% [markdown]
# # Content of the Project
# (Please clean and push to GitHub every week)
#
# 1. Set Up
# 2. Web-scraping
# 3. Simple Solutions
# 4. Content-based Filtering
# 5. Collaborative Filtering

# %% [markdown]
# # Simple Solutions

# %% [markdown]
# ## Highly-rated books
# Recommend highly-rated books in each genre
